# %% [markdown]
# # Translation (TensorFlow)

# %% [markdown]
# Install the Transformers, Datasets, and Evaluate libraries to run this notebook.

# %%
# !pip install datasets evaluate transformers[sentencepiece]
# !apt install git-lfs
# Out:
# Requirement already satisfied: datasets in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (2.17.0)
# Requirement already satisfied: evaluate in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (0.4.1)
# Requirement already satisfied: transformers[sentencepiece] in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (4.37.2)
# Requirement already satisfied: filelock in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (3.13.1)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (1.26.4)
# Requirement already satisfied: pyarrow>=12.0.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (15.0.0)
# Requirement already satisfied: pyarrow-hotfix in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (0.6)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (2.2.0)
# Requirement already satisfied: requests>=2.19.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (2.31.0)
# Requirement already satisfied: tqdm>=4.62.1 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (4.66.2)
# Requirement already satisfied: xxhash in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (3.4.1)
# Requirement already satisfied: multiprocess in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (0.70.16)
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (2023.10.0)
# Requirement already satisfied: aiohttp in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (3.9.3)
# Requirement already satisfied: huggingface-hub>=0.19.4 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (0.20.3)
# Requirement already satisfied: packaging in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from datasets) (6.0.1)
# Requirement already satisfied: responses<0.19 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from evaluate) (0.18.0)
# Requirement already satisfied: regex!=2019.12.17 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from transformers[sentencepiece]) (2023.12.25)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from transformers[sentencepiece]) (0.15.2)
# Requirement already satisfied: safetensors>=0.4.1 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from transformers[sentencepiece]) (0.4.2)
# Requirement already satisfied: sentencepiece!=0.1.92,>=0.1.91 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from transformers[sentencepiece]) (0.1.99)
# Requirement already satisfied: protobuf in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from transformers[sentencepiece]) (4.25.3)
# Requirement already satisfied: aiosignal>=1.1.2 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from aiohttp->datasets) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from aiohttp->datasets) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from aiohttp->datasets) (4.0.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from huggingface-hub>=0.19.4->datasets) (4.9.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from requests>=2.19.0->datasets) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from requests>=2.19.0->datasets) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from requests>=2.19.0->datasets) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from requests>=2.19.0->datasets) (2024.2.2)
# Requirement already satisfied: colorama in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tqdm>=4.62.1->datasets) (0.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from pandas->datasets) (2024.1)
# Requirement already satisfied: six>=1.5 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# "apt" ­Ґ пў«пҐвбп ў­гваҐ­­Ґ© Ё«Ё ў­Ґи­Ґ©
# Є®¬ ­¤®©, ЁбЇ®«­пҐ¬®© Їа®Ја ¬¬®© Ё«Ё Ї ЄҐв­л¬ д ©«®¬.

# %% [markdown]
# You will need to setup git, adapt your email and name in the following cell.

# %%
# !git config --global user.email "you@example.com"
# !git config --global user.name "Your Name"

# %% [markdown]
# You will also need to be logged in to the Hugging Face Hub. Execute the following and enter your credentials.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
from datasets import load_dataset

raw_datasets = load_dataset("kde4", lang1="en", lang2="fr")
# Out:
# C:\Users\USER\Documents\GitHub\Translation_fine_tuning\venv\lib\site-packages\datasets\load.py:1454: FutureWarning: The repository for kde4 contains custom code which must be executed to correctly load the dataset. You can inspect the repository content at https://hf.co/datasets/kde4
# You can avoid this message in future by passing the argument `trust_remote_code=True`.
# Passing `trust_remote_code=True` will be mandatory to load this dataset from the next major release of `datasets`.
#   warnings.warn(

# %%
raw_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 210173
#     })
# })

# %%
split_datasets = raw_datasets["train"].train_test_split(train_size=0.9, seed=20)
split_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 189155
#     })
#     test: Dataset({
#         features: ['id', 'translation'],
#         num_rows: 21018
#     })
# })

# %%
split_datasets["validation"] = split_datasets.pop("test")

# %%
split_datasets["train"][1]["translation"]
# Out:
# {'en': 'Default to expanded threads',
#  'fr': 'Par défaut, développer les fils de discussion'}

# %%
# !pip install --upgrade tensorflow
# Out:
# Requirement already satisfied: tensorflow in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (2.15.0)
# Requirement already satisfied: tensorflow-intel==2.15.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow) (2.15.0)
# Requirement already satisfied: absl-py>=1.0.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.1.0)
# Requirement already satisfied: astunparse>=1.6.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.6.3)
# Requirement already satisfied: flatbuffers>=23.5.26 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.5.26)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.5.4)
# Requirement already satisfied: google-pasta>=0.1.1 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: h5py>=2.9.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.10.0)
# Requirement already satisfied: libclang>=13.0.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (16.0.6)
# Requirement already satisfied: ml-dtypes~=0.2.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.2.0)
# Requirement already satisfied: numpy<2.0.0,>=1.23.5 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.26.4)
# Requirement already satisfied: opt-einsum>=2.3.2 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (3.3.0)
# Requirement already satisfied: packaging in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (23.2)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<5.0.0dev,>=3.20.3 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.25.3)
# Requirement already satisfied: setuptools in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (68.2.0)
# Requirement already satisfied: six>=1.12.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.16.0)
# Requirement already satisfied: termcolor>=1.1.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.4.0)
# Requirement already satisfied: typing-extensions>=3.6.6 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (4.9.0)
# Requirement already satisfied: wrapt<1.15,>=1.11.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.14.1)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (0.31.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (1.60.1)
# Requirement already satisfied: tensorboard<2.16,>=2.15 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.2)
# Requirement already satisfied: tensorflow-estimator<2.16,>=2.15.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: keras<2.16,>=2.15.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorflow-intel==2.15.0->tensorflow) (2.15.0)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from astunparse>=1.6.0->tensorflow-intel==2.15.0->tensorflow) (0.41.2)
# Requirement already satisfied: google-auth<3,>=1.6.3 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.28.0)
# Requirement already satisfied: google-auth-oauthlib<2,>=0.5 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.2.0)
# Requirement already satisfied: markdown>=2.6.8 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.5.2)
# Requirement already satisfied: requests<3,>=2.21.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.31.0)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.7.2)
# Requirement already satisfied: werkzeug>=1.0.1 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.0.1)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (5.3.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (1.3.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.2.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from requests<3,>=2.21.0->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2024.2.2)
# Requirement already satisfied: MarkupSafe>=2.1.1 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from werkzeug>=1.0.1->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (2.1.5)
# Requirement already satisfied: pyasn1<0.6.0,>=0.4.6 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (0.5.1)
# Requirement already satisfied: oauthlib>=3.0.0 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<2,>=0.5->tensorboard<2.16,>=2.15->tensorflow-intel==2.15.0->tensorflow) (3.2.2)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from transformers import pipeline

model_checkpoint = "Helsinki-NLP/opus-mt-en-fr"
translator = pipeline("translation", model=model_checkpoint)
translator("Default to expanded threads")
# Out:
# WARNING:tensorflow:From C:\Users\USER\Documents\GitHub\Translation_fine_tuning\venv\lib\site-packages\keras\src\losses.py:2976: The name tf.losses.sparse_softmax_cross_entropy is deprecated. Please use tf.compat.v1.losses.sparse_softmax_cross_entropy instead.
# pytorch_model.bin:   0%|          | 0.00/301M [00:00<?, ?B/s]
# C:\Users\USER\Documents\GitHub\Translation_fine_tuning\venv\lib\site-packages\huggingface_hub\file_download.py:149: UserWarning: `huggingface_hub` cache-system uses symlinks by default to efficiently store duplicated files but your machine does not support them in C:\Users\USER\.cache\huggingface\hub\models--Helsinki-NLP--opus-mt-en-fr. Caching files will still work but in a degraded version that might require more space on your disk. This warning can be disabled by setting the `HF_HUB_DISABLE_SYMLINKS_WARNING` environment variable. For more details, see https://huggingface.co/docs/huggingface_hub/how-to-cache#limitations.
# To support symlinks on Windows, you either need to activate Developer Mode or to run Python as an administrator. In order to see activate developer mode, see this article: https://docs.microsoft.com/en-us/windows/apps/get-started/enable-your-device-for-development
#   warnings.warn(message)
# generation_config.json:   0%|          | 0.00/293 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/42.0 [00:00<?, ?B/s]
# source.spm:   0%|          | 0.00/778k [00:00<?, ?B/s]
# target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.34M [00:00<?, ?B/s]
# C:\Users\USER\Documents\GitHub\Translation_fine_tuning\venv\lib\site-packages\transformers\models\marian\tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")
# [{'translation_text': 'Par défaut pour les threads élargis'}]

# %%
split_datasets["train"][172]["translation"]
# Out:
# {'en': 'Unable to import %1 using the OFX importer plugin. This file is not the correct format.',
#  'fr': "Impossible d'importer %1 en utilisant le module d'extension d'importation OFX. Ce fichier n'a pas un format correct."}

# %%
translator(
    "Unable to import %1 using the OFX importer plugin. This file is not the correct format."
)
# Out:
# [{'translation_text': "Impossible d'importer %1 en utilisant le plugin d'importateur OFX. Ce fichier n'est pas le bon format."}]

# %%
from transformers import AutoTokenizer

model_checkpoint = "Helsinki-NLP/opus-mt-en-fr"
tokenizer = AutoTokenizer.from_pretrained(model_checkpoint, return_tensors="pt")
# Out:
# C:\Users\USER\Documents\GitHub\Translation_fine_tuning\venv\lib\site-packages\transformers\models\marian\tokenization_marian.py:197: UserWarning: Recommended: pip install sacremoses.
#   warnings.warn("Recommended: pip install sacremoses.")

# %%
en_sentence = split_datasets["train"][1]["translation"]["en"]
fr_sentence = split_datasets["train"][1]["translation"]["fr"]

inputs = tokenizer(en_sentence, text_target=fr_sentence)
inputs
# Out:
# {'input_ids': [47591, 12, 9842, 19634, 9, 0], 'attention_mask': [1, 1, 1, 1, 1, 1], 'labels': [577, 5891, 2, 3184, 16, 2542, 5, 1710, 0]}

# %%
wrong_targets = tokenizer(fr_sentence)
print(tokenizer.convert_ids_to_tokens(wrong_targets["input_ids"]))
print(tokenizer.convert_ids_to_tokens(inputs["labels"]))
# Out:
# ['▁Par', '▁dé', 'f', 'aut', ',', '▁dé', 've', 'lop', 'per', '▁les', '▁fil', 's', '▁de', '▁discussion', '</s>']
# ['▁Par', '▁défaut', ',', '▁développer', '▁les', '▁fils', '▁de', '▁discussion', '</s>']

# %%
max_length = 128


def preprocess_function(examples):
    inputs = [ex["en"] for ex in examples["translation"]]
    targets = [ex["fr"] for ex in examples["translation"]]
    model_inputs = tokenizer(
        inputs, text_target=targets, max_length=max_length, truncation=True
    )
    return model_inputs

# %%
tokenized_datasets = split_datasets.map(
    preprocess_function,
    batched=True,
    remove_columns=split_datasets["train"].column_names,
)
# Out:
# Map:   0%|          | 0/189155 [00:00<?, ? examples/s]
# Map:   0%|          | 0/21018 [00:00<?, ? examples/s]

# %%
tokenized_datasets
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 189155
#     })
#     validation: Dataset({
#         features: ['input_ids', 'attention_mask', 'labels'],
#         num_rows: 21018
#     })
# })

# %%
from transformers import TFAutoModelForSeq2SeqLM

model = TFAutoModelForSeq2SeqLM.from_pretrained(model_checkpoint, from_pt=True)
# Out:
# WARNING:tensorflow:From C:\Users\USER\Documents\GitHub\Translation_fine_tuning\venv\lib\site-packages\keras\src\backend.py:873: The name tf.get_default_graph is deprecated. Please use tf.compat.v1.get_default_graph instead.
# All PyTorch model weights were used when initializing TFMarianMTModel.
#
# All the weights of TFMarianMTModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFMarianMTModel for predictions without further training.

# %%
from transformers import DataCollatorForSeq2Seq

data_collator = DataCollatorForSeq2Seq(tokenizer, model=model, return_tensors="tf")

# %%
batch = data_collator([tokenized_datasets["train"][i] for i in range(1, 3)])
batch.keys()
# Out:
# dict_keys(['input_ids', 'attention_mask', 'labels', 'decoder_input_ids'])

# %%
batch["labels"]
# Out:
# <tf.Tensor: shape=(2, 16), dtype=int32, numpy=
# array([[  577,  5891,     2,  3184,    16,  2542,     5,  1710,     0,
#          -100,  -100,  -100,  -100,  -100,  -100,  -100],
#        [ 1211,     3,    49,  9409,  1211,     3, 29140,   817,  3124,
#           817,   550,  7032,  5821,  7907, 12649,     0]])>

# %%
batch["decoder_input_ids"]
# Out:
# <tf.Tensor: shape=(2, 16), dtype=int32, numpy=
# array([[59513,   577,  5891,     2,  3184,    16,  2542,     5,  1710,
#             0, 59513, 59513, 59513, 59513, 59513, 59513],
#        [59513,  1211,     3,    49,  9409,  1211,     3, 29140,   817,
#          3124,   817,   550,  7032,  5821,  7907, 12649]])>

# %%
for i in range(1, 3):
    print(tokenized_datasets["train"][i]["labels"])
# Out:
# [577, 5891, 2, 3184, 16, 2542, 5, 1710, 0]
# [1211, 3, 49, 9409, 1211, 3, 29140, 817, 3124, 817, 550, 7032, 5821, 7907, 12649, 0]

# %%
tf_train_dataset = model.prepare_tf_dataset(
    tokenized_datasets["train"],
    collate_fn=data_collator,
    shuffle=True,
    batch_size=32,
)
tf_eval_dataset = model.prepare_tf_dataset(
    tokenized_datasets["validation"],
    collate_fn=data_collator,
    shuffle=False,
    batch_size=16,
)

# %%
# !pip install sacrebleu
# Out:
# Collecting sacrebleu
#   Obtaining dependency information for sacrebleu from https://files.pythonhosted.org/packages/de/ea/025db0a39337b63d4728a900d262c39c3029b0fe76a9876ce6297b1aa6a0/sacrebleu-2.4.0-py3-none-any.whl.metadata
#   Downloading sacrebleu-2.4.0-py3-none-any.whl.metadata (57 kB)
#      ---------------------------------------- 0.0/57.4 kB ? eta -:--:--
#      --------------------------- ---------- 41.0/57.4 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 57.4/57.4 kB 761.0 kB/s eta 0:00:00
# Collecting portalocker (from sacrebleu)
#   Obtaining dependency information for portalocker from https://files.pythonhosted.org/packages/17/9e/87671efcca80ba6203811540ed1f9c0462c1609d2281d7b7f53cef05da3d/portalocker-2.8.2-py3-none-any.whl.metadata
#   Downloading portalocker-2.8.2-py3-none-any.whl.metadata (8.5 kB)
# Requirement already satisfied: regex in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from sacrebleu) (2023.12.25)
# Collecting tabulate>=0.8.9 (from sacrebleu)
#   Downloading tabulate-0.9.0-py3-none-any.whl (35 kB)
# Requirement already satisfied: numpy>=1.17 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from sacrebleu) (1.26.4)
# Requirement already satisfied: colorama in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from sacrebleu) (0.4.6)
# Collecting lxml (from sacrebleu)
#   Obtaining dependency information for lxml from https://files.pythonhosted.org/packages/dc/3d/53c664318c9ab5bfbe9b9b3b6be0d04a2fa161f4cd35d731d27a0f754253/lxml-5.1.0-cp310-cp310-win_amd64.whl.metadata
#   Downloading lxml-5.1.0-cp310-cp310-win_amd64.whl.metadata (3.6 kB)
# Requirement already satisfied: pywin32>=226 in c:\users\user\documents\github\translation_fine_tuning\venv\lib\site-packages (from portalocker->sacrebleu) (306)
# Downloading sacrebleu-2.4.0-py3-none-any.whl (106 kB)
#    ---------------------------------------- 0.0/106.3 kB ? eta -:--:--
#    ---------------------------------- ----- 92.2/106.3 kB 2.6 MB/s eta 0:00:01
#    ---------------------------------------- 106.3/106.3 kB 1.5 MB/s eta 0:00:00
# Downloading lxml-5.1.0-cp310-cp310-win_amd64.whl (3.9 MB)
#    ---------------------------------------- 0.0/3.9 MB ? eta -:--:--
#    -- ------------------------------------- 0.3/3.9 MB 5.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 0.4/3.9 MB 4.4 MB/s eta 0:00:01
#    ------ --------------------------------- 0.6/3.9 MB 4.2 MB/s eta 0:00:01
#    -------- ------------------------------- 0.8/3.9 MB 4.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 1.1/3.9 MB 4.6 MB/s eta 0:00:01
#    ------------- -------------------------- 1.3/3.9 MB 4.5 MB/s eta 0:00:01
#    ---------------- ----------------------- 1.6/3.9 MB 4.9 MB/s eta 0:00:01
#    ------------------ --------------------- 1.8/3.9 MB 4.8 MB/s eta 0:00:01
#    --------------------- ------------------ 2.1/3.9 MB 4.7 MB/s eta 0:00:01
#    ------------------------ --------------- 2.4/3.9 MB 4.9 MB/s eta 0:00:01
#    -------------------------- ------------- 2.6/3.9 MB 4.9 MB/s eta 0:00:01
#    ----------------------------- ---------- 2.9/3.9 MB 5.0 MB/s eta 0:00:01
#    ------------------------------- -------- 3.1/3.9 MB 4.9 MB/s eta 0:00:01
#    --------------------------------- ------ 3.3/3.9 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------ --- 3.5/3.9 MB 4.9 MB/s eta 0:00:01
#    -------------------------------------- - 3.7/3.9 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  3.9/3.9 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.9/3.9 MB 4.6 MB/s eta 0:00:00
# Downloading portalocker-2.8.2-py3-none-any.whl (17 kB)
# Installing collected packages: tabulate, portalocker, lxml, sacrebleu
# Successfully installed lxml-5.1.0 portalocker-2.8.2 sacrebleu-2.4.0 tabulate-0.9.0
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import evaluate

metric = evaluate.load("sacrebleu")
# Out:
# Downloading builder script:   0%|          | 0.00/8.15k [00:00<?, ?B/s]

# %%
predictions = [
    "This plugin lets you translate web pages between several languages automatically."
]
references = [
    [
        "This plugin allows you to automatically translate web pages between several languages."
    ]
]
metric.compute(predictions=predictions, references=references)
# Out:
# {'score': 46.750469682990165,
#  'counts': [11, 6, 4, 3],
#  'totals': [12, 11, 10, 9],
#  'precisions': [91.66666666666667,
#   54.54545454545455,
#   40.0,
#   33.333333333333336],
#  'bp': 0.9200444146293233,
#  'sys_len': 12,
#  'ref_len': 13}

# %%
predictions = ["This This This This"]
references = [
    [
        "This plugin allows you to automatically translate web pages between several languages."
    ]
]
metric.compute(predictions=predictions, references=references)
# Out:
# {'score': 1.683602693167689,
#  'counts': [1, 0, 0, 0],
#  'totals': [4, 3, 2, 1],
#  'precisions': [25.0, 16.666666666666668, 12.5, 12.5],
#  'bp': 0.10539922456186433,
#  'sys_len': 4,
#  'ref_len': 13}

# %%
predictions = ["This plugin"]
references = [
    [
        "This plugin allows you to automatically translate web pages between several languages."
    ]
]
metric.compute(predictions=predictions, references=references)
# Out:
# {'score': 0.0,
#  'counts': [2, 1, 0, 0],
#  'totals': [2, 1, 0, 0],
#  'precisions': [100.0, 100.0, 0.0, 0.0],
#  'bp': 0.004086771438464067,
#  'sys_len': 2,
#  'ref_len': 13}

# %%
import numpy as np
import tensorflow as tf
from tqdm import tqdm

generation_data_collator = DataCollatorForSeq2Seq(
    tokenizer, model=model, return_tensors="tf", pad_to_multiple_of=128
)

tf_generate_dataset = model.prepare_tf_dataset(
    tokenized_datasets["validation"],
    collate_fn=generation_data_collator,
    shuffle=False,
    batch_size=8,
)


#@tf.function(jit_compile=True)
def generate_with_xla(batch):
    return model.generate(
        input_ids=batch["input_ids"],
        attention_mask=batch["attention_mask"],
        max_new_tokens=128,
    )


def compute_metrics():
    all_preds = []
    all_labels = []
    count = 0
    for batch, labels in tqdm(tf_generate_dataset):
        if count == 1:
          break
        predictions = generate_with_xla(batch)
        decoded_preds = tokenizer.batch_decode(predictions, skip_special_tokens=True)
        labels = labels.numpy()
        labels = np.where(labels != -100, labels, tokenizer.pad_token_id)
        decoded_labels = tokenizer.batch_decode(labels, skip_special_tokens=True)
        decoded_preds = [pred.strip() for pred in decoded_preds]
        decoded_labels = [[label.strip()] for label in decoded_labels]
        all_preds.extend(decoded_preds)
        all_labels.extend(decoded_labels)
        count +=1

    result = metric.compute(predictions=all_preds, references=all_labels)
    return {"bleu": result["score"]}

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
print(compute_metrics())
# Out:
#   0%|                                                                                                                                        | 1/2628 [02:31<110:16:36, 151.12s/it]
# {'bleu': 21.249561573935125}

# %%
from transformers import create_optimizer
from transformers.keras_callbacks import PushToHubCallback
import tensorflow as tf

# The number of training steps is the number of samples in the dataset, divided by the batch size then multiplied
# by the total number of epochs. Note that the tf_train_dataset here is a batched tf.data.Dataset,
# not the original Hugging Face Dataset, so its len() is already num_samples // batch_size.
num_epochs = 1
num_train_steps = len(tf_train_dataset) * num_epochs

optimizer, schedule = create_optimizer(
    init_lr=5e-5,
    num_warmup_steps=0,
    num_train_steps=num_train_steps,
    weight_decay_rate=0.01,
)
model.compile(optimizer=optimizer)

# Train in mixed-precision float16
tf.keras.mixed_precision.set_global_policy("mixed_float16")

# %%
from transformers.keras_callbacks import PushToHubCallback

callback = PushToHubCallback(
    output_dir="marian-finetuned-kde4-en-to-fr", tokenizer=tokenizer
)

model.fit(
    tf_train_dataset,
    validation_data=tf_eval_dataset,
    callbacks=[callback],
    epochs=num_epochs,
)

# %%
print(compute_metrics())

# %%
model.summary()

# %%
tf.keras.mixed_precision.set_global_policy("float32")

# %%
from transformers import pipeline

# Replace this with your own checkpoint
model_checkpoint = "serhii-korobchenko/marian-finetuned-kde4-en-to-fr"
translator = pipeline("translation", model=model_checkpoint)
translator("Default to expanded threads")

# %%
translator(
    "Unable to import %1 using the OFX importer plugin. This file is not the correct format."
)

# %%
print(compute_metrics())
